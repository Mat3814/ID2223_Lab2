# %% [markdown]
# # Merge the base model with the LoRa in a GGUF file executable by a CPU

# %% [markdown]
# ### Merging

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel

# Paths to your base model and adapter
base_model_path = "unsloth/Llama-3.2-3B-Instruct"  # Original model (e.g., LLaMA)
adapter_model_path = "ID2223-Lab/llama_lora_adapter"  # LoRA adapter files (e.g., adapter_model.safetensors)

# Load base model and tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model_path)
base_model = AutoModelForCausalLM.from_pretrained(base_model_path)

# Load the LoRA adapter and merge into the base model
model = PeftModel.from_pretrained(base_model, adapter_model_path)
model = model.merge_and_unload()  # Merge LoRA weights into the base model

# Save the fully merged model
model.save_pretrained("merged_model")
tokenizer.save_pretrained("merged_model")  # Save the tokenizer too
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/54.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/928 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/6.43G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/184 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/738 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/97.3M [00:00<?, ?B/s]
# ('merged_model/tokenizer_config.json',
#  'merged_model/special_tokens_map.json',
#  'merged_model/tokenizer.json')

# %%
# !git clone https://github.com/ggerganov/llama.cpp.git
# Out:
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 38883, done.
# remote: Counting objects: 100% (24123/24123), done.
# remote: Compressing objects: 100% (1218/1218), done.
# remote: Total 38883 (delta 23337), reused 22931 (delta 22904), pack-reused 14760 (from 1)
# Receiving objects: 100% (38883/38883), 56.74 MiB | 16.54 MiB/s, done.
# Resolving deltas: 100% (28901/28901), done.

# %%
# !pip install -r llama.cpp/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/cpu
# Requirement already satisfied: numpy~=1.26.4 in /usr/local/lib/python3.10/dist-packages (from -r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 1)) (1.26.4)
# Requirement already satisfied: sentencepiece~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from -r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 2)) (0.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.45.1 in /usr/local/lib/python3.10/dist-packages (from -r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (4.46.2)
# Collecting gguf>=0.1.0 (from -r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 4))
#   Downloading gguf-0.10.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: protobuf<5.0.0,>=4.21.0 in /usr/local/lib/python3.10/dist-packages (from -r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 5)) (4.25.5)
# Collecting torch~=2.2.1 (from -r llama.cpp/./requirements/requirements-convert_hf_to_gguf.txt (line 3))
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.2.2%2Bcpu-cp310-cp310-linux_x86_64.whl (186.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.8/186.8 MB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (0.26.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch~=2.2.1->-r llama.cpp/./requirements/requirements-convert_hf_to_gguf.txt (line 3)) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch~=2.2.1->-r llama.cpp/./requirements/requirements-convert_hf_to_gguf.txt (line 3)) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch~=2.2.1->-r llama.cpp/./requirements/requirements-convert_hf_to_gguf.txt (line 3)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch~=2.2.1->-r llama.cpp/./requirements/requirements-convert_hf_to_gguf.txt (line 3)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch~=2.2.1->-r llama.cpp/./requirements/requirements-convert_hf_to_gguf.txt (line 3)) (2024.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch~=2.2.1->-r llama.cpp/./requirements/requirements-convert_hf_to_gguf.txt (line 3)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.45.1->-r llama.cpp/./requirements/requirements-convert_legacy_llama.txt (line 3)) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch~=2.2.1->-r llama.cpp/./requirements/requirements-convert_hf_to_gguf.txt (line 3)) (1.3.0)
# Downloading gguf-0.10.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 7.5 MB/s eta 0:00:00
# Installing collected packages: gguf, torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu121
#     Uninstalling torch-2.5.1+cu121:
#       Successfully uninstalled torch-2.5.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu121 requires torch==2.5.1, but you have torch 2.2.2+cpu which is incompatible.
# torchvision 0.20.1+cu121 requires torch==2.5.1, but you have torch 2.2.2+cpu which is incompatible.
# Successfully installed gguf-0.10.0 torch-2.2.2+cpu

# %%
# !python llama.cpp/convert_hf_to_gguf.py merged_model --outfile FineTune_Llama.gguf --outtype q8_0
# Out:
# INFO:hf-to-gguf:Loading model: merged_model
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:rope_freqs.weight,           torch.float32 --> F32, shape = {64}
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: loading model part 'model-00001-of-00003.safetensors'
# INFO:hf-to-gguf:token_embd.weight,           torch.float32 --> Q8_0, shape = {3072, 128256}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,       torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,       torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,         torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,       torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.0.attn_k.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.0.attn_output.weight,    torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.0.attn_q.weight,         torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.0.attn_v.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.1.attn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.1.ffn_down.weight,       torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight,       torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.1.ffn_up.weight,         torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.1.ffn_norm.weight,       torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.1.attn_k.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.1.attn_output.weight,    torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.1.attn_q.weight,         torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.1.attn_v.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.2.attn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.2.ffn_down.weight,       torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight,       torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.2.ffn_up.weight,         torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.2.ffn_norm.weight,       torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.2.attn_k.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.2.attn_output.weight,    torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.2.attn_q.weight,         torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.2.attn_v.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.3.attn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.3.ffn_down.weight,       torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight,       torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.3.ffn_up.weight,         torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.3.ffn_norm.weight,       torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.3.attn_k.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.3.attn_output.weight,    torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.3.attn_q.weight,         torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.3.attn_v.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.4.attn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.4.ffn_down.weight,       torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight,       torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.4.ffn_up.weight,         torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.4.ffn_norm.weight,       torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.4.attn_k.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.4.attn_output.weight,    torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.4.attn_q.weight,         torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.4.attn_v.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.5.attn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.5.ffn_down.weight,       torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight,       torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.5.ffn_up.weight,         torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.5.ffn_norm.weight,       torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.5.attn_k.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.5.attn_output.weight,    torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.5.attn_q.weight,         torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.5.attn_v.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.6.attn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.6.ffn_down.weight,       torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight,       torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.6.ffn_up.weight,         torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.6.ffn_norm.weight,       torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.6.attn_k.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.6.attn_output.weight,    torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.6.attn_q.weight,         torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.6.attn_v.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.7.attn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.7.ffn_down.weight,       torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.7.ffn_gate.weight,       torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.7.ffn_up.weight,         torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.7.ffn_norm.weight,       torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.7.attn_k.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.7.attn_output.weight,    torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.7.attn_q.weight,         torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.7.attn_v.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.8.ffn_gate.weight,       torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.8.attn_k.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.8.attn_output.weight,    torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.8.attn_q.weight,         torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.8.attn_v.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00002-of-00003.safetensors'
# INFO:hf-to-gguf:blk.10.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.10.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.10.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.10.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.10.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.10.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.10.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.10.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.11.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.11.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.11.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.11.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.11.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.11.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.11.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.11.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.12.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.12.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.12.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.12.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.12.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.12.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.12.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.12.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.13.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.13.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.13.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.13.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.13.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.13.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.13.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.13.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.13.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.14.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.14.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.14.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.14.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.14.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.14.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.14.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.14.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.14.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.15.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.15.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.15.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.15.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.15.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.15.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.15.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.15.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.15.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.16.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.16.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.16.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.16.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.16.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.16.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.16.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.16.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.16.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.17.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.17.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.17.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.17.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.17.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.17.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.17.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.17.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.17.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.18.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.18.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.18.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.18.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.18.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.18.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.18.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.18.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.18.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.19.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.19.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.19.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.19.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.19.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.19.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.19.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.19.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.19.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.20.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.20.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.20.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.20.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.20.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.20.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.8.attn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.8.ffn_down.weight,       torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.8.ffn_up.weight,         torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.8.ffn_norm.weight,       torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.9.attn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.9.ffn_down.weight,       torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.9.ffn_gate.weight,       torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.9.ffn_up.weight,         torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.9.ffn_norm.weight,       torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.9.attn_k.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.9.attn_output.weight,    torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.9.attn_q.weight,         torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.9.attn_v.weight,         torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00003-of-00003.safetensors'
# INFO:hf-to-gguf:blk.20.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.20.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.20.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.21.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.21.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.21.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.21.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.21.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.21.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.21.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.21.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.21.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.22.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.22.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.22.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.22.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.22.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.22.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.22.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.22.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.22.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.23.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.23.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.23.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.23.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.23.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.23.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.23.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.23.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.23.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.24.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.24.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.24.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.24.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.24.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.24.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.24.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.24.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.24.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.25.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.25.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.25.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.25.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.25.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.25.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.25.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.25.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.25.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.26.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.26.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.26.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.26.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.26.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.26.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.26.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.26.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.26.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.27.attn_norm.weight,     torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.27.ffn_down.weight,      torch.float32 --> Q8_0, shape = {8192, 3072}
# INFO:hf-to-gguf:blk.27.ffn_gate.weight,      torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.27.ffn_up.weight,        torch.float32 --> Q8_0, shape = {3072, 8192}
# INFO:hf-to-gguf:blk.27.ffn_norm.weight,      torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:blk.27.attn_k.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:blk.27.attn_output.weight,   torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.27.attn_q.weight,        torch.float32 --> Q8_0, shape = {3072, 3072}
# INFO:hf-to-gguf:blk.27.attn_v.weight,        torch.float32 --> Q8_0, shape = {3072, 1024}
# INFO:hf-to-gguf:output_norm.weight,          torch.float32 --> F32, shape = {3072}
# INFO:hf-to-gguf:Set meta model
# INFO:hf-to-gguf:Set model parameters
# INFO:hf-to-gguf:gguf: context length = 131072
# INFO:hf-to-gguf:gguf: embedding length = 3072
# INFO:hf-to-gguf:gguf: feed forward length = 8192
# INFO:hf-to-gguf:gguf: head count = 24
# INFO:hf-to-gguf:gguf: key-value head count = 8
# INFO:hf-to-gguf:gguf: rope theta = 500000.0
# INFO:hf-to-gguf:gguf: rms norm epsilon = 1e-05
# INFO:hf-to-gguf:gguf: file type = 7
# INFO:hf-to-gguf:Set model tokenizer
# INFO:gguf.vocab:Adding 280147 merge(s).
# INFO:gguf.vocab:Setting special token type bos to 128000
# INFO:gguf.vocab:Setting special token type eos to 128009
# INFO:gguf.vocab:Setting special token type pad to 128004
# INFO:gguf.vocab:Setting chat_template to {{- bos_token }}
# {%- if custom_tools is defined %}
#     {%- set tools = custom_tools %}
# {%- endif %}
# {%- if not tools_in_user_message is defined %}
#     {%- set tools_in_user_message = true %}
# {%- endif %}
# {%- if not date_string is defined %}
#     {%- if strftime_now is defined %}
#         {%- set date_string = strftime_now("%d %b %Y") %}
#     {%- else %}
#         {%- set date_string = "26 Jul 2024" %}
#     {%- endif %}
# {%- endif %}
# {%- if not tools is defined %}
#     {%- set tools = none %}
# {%- endif %}
#
# {#- This block extracts the system message, so we can slot it into the right place. #}
# {%- if messages[0]['role'] == 'system' %}
#     {%- set system_message = messages[0]['content']|trim %}
#     {%- set messages = messages[1:] %}
# {%- else %}
#     {%- set system_message = "" %}
# {%- endif %}
#
# {#- System message #}
# {{- "<|start_header_id|>system<|end_header_id|>\n\n" }}
# {%- if tools is not none %}
#     {{- "Environment: ipython\n" }}
# {%- endif %}
# {{- "Cutting Knowledge Date: December 2023\n" }}
# {{- "Today Date: " + date_string + "\n\n" }}
# {%- if tools is not none and not tools_in_user_message %}
#     {{- "You have access to the following functions. To call a function, please respond with JSON for a function call." }}
#     {{- 'Respond in the format {"name": function name, "parameters": dictionary of argument name and its value}.' }}
#     {{- "Do not use variables.\n\n" }}
#     {%- for t in tools %}
#         {{- t | tojson(indent=4) }}
#         {{- "\n\n" }}
#     {%- endfor %}
# {%- endif %}
# {{- system_message }}
# {{- "<|eot_id|>" }}
#
# {#- Custom tools are passed in a user message with some extra guidance #}
# {%- if tools_in_user_message and not tools is none %}
#     {#- Extract the first user message so we can plug it in here #}
#     {%- if messages | length != 0 %}
#         {%- set first_user_message = messages[0]['content']|trim %}
#         {%- set messages = messages[1:] %}
#     {%- else %}
#         {{- raise_exception("Cannot put tools in the first user message when there's no first user message!") }}
# {%- endif %}
#     {{- '<|start_header_id|>user<|end_header_id|>\n\n' -}}
#     {{- "Given the following functions, please respond with a JSON for a function call " }}
#     {{- "with its proper arguments that best answers the given prompt.\n\n" }}
#     {{- 'Respond in the format {"name": function name, "parameters": dictionary of argument name and its value}.' }}
#     {{- "Do not use variables.\n\n" }}
#     {%- for t in tools %}
#         {{- t | tojson(indent=4) }}
#         {{- "\n\n" }}
#     {%- endfor %}
#     {{- first_user_message + "<|eot_id|>"}}
# {%- endif %}
#
# {%- for message in messages %}
#     {%- if not (message.role == 'ipython' or message.role == 'tool' or 'tool_calls' in message) %}
#         {{- '<|start_header_id|>' + message['role'] + '<|end_header_id|>\n\n'+ message['content'] | trim + '<|eot_id|>' }}
#     {%- elif 'tool_calls' in message %}
#         {%- if not message.tool_calls|length == 1 %}
#             {{- raise_exception("This model only supports single tool-calls at once!") }}
#         {%- endif %}
#         {%- set tool_call = message.tool_calls[0].function %}
#         {{- '<|start_header_id|>assistant<|end_header_id|>\n\n' -}}
#         {{- '{"name": "' + tool_call.name + '", ' }}
#         {{- '"parameters": ' }}
#         {{- tool_call.arguments | tojson }}
#         {{- "}" }}
#         {{- "<|eot_id|>" }}
#     {%- elif message.role == "tool" or message.role == "ipython" %}
#         {{- "<|start_header_id|>ipython<|end_header_id|>\n\n" }}
#         {%- if message.content is mapping or message.content is iterable %}
#             {{- message.content | tojson }}
#         {%- else %}
#             {{- message.content }}
#         {%- endif %}
#         {{- "<|eot_id|>" }}
#     {%- endif %}
# {%- endfor %}
# {%- if add_generation_prompt %}
#     {{- '<|start_header_id|>assistant<|end_header_id|>\n\n' }}
# {%- endif %}
#
# INFO:hf-to-gguf:Set model quantization version
# INFO:gguf.gguf_writer:Writing the following files:
# INFO:gguf.gguf_writer:FineTune_Llama.gguf: n_tensors = 255, total_size = 3.4G
# Writing: 100% 3.41G/3.41G [01:16<00:00, 44.7Mbyte/s]
# INFO:hf-to-gguf:Model successfully exported to FineTune_Llama.gguf

# %%
from huggingface_hub import login

login(token="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")

# %%
from huggingface_hub import HfApi, upload_file

# Initialize the HfApi class
api = HfApi()

api.upload_file(
    path_or_fileobj="FineTune_Llama.gguf",
    path_in_repo="FineTune_Llama.gguf",
    repo_id="ID2223-Lab/llama_lora_merged_GGUF",
    repo_type="model",

)
# Out:
# FineTune_Llama.gguf:   0%|          | 0.00/3.42G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/ID2223-Lab/llama_lora_merged_GGUF/commit/5a051aca1e68a75698deac7deeb389f9331ffa65', commit_message='Upload FineTune_Llama.gguf with huggingface_hub', commit_description='', oid='5a051aca1e68a75698deac7deeb389f9331ffa65', pr_url=None, repo_url=RepoUrl('https://huggingface.co/ID2223-Lab/llama_lora_merged_GGUF', endpoint='https://huggingface.co', repo_type='model', repo_id='ID2223-Lab/llama_lora_merged_GGUF'), pr_revision=None, pr_num=None)
